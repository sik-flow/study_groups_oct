# %%
import pandas as pd
from sklearn.datasets import make_blobs, make_circles, make_moons
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from mlxtend.plotting import plot_decision_regions
from sklearn.tree import DecisionTreeClassifier

# %%
x, y = make_blobs(n_samples = 10000, n_features = 2, centers = 2, cluster_std=3.5)

# %%
# %%time
clf.fit(x, y)
clf.score(x, y)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# CPU times: user 34min 10s, sys: 13.8 s, total: 34min 24s
# Wall time: 34min 50s
# 0.599

# %%
# %%time
dt.fit(x, y)
dt.score(x, y)
# Out:
# CPU times: user 34.5 ms, sys: 2.5 ms, total: 37 ms
# Wall time: 37.2 ms
# 1.0

# %%
dt = DecisionTreeClassifier()

# %%
x.shape
# Out:
# (1000, 2)

# %%
y.shape
# Out:
# (1000,)

# %%
x
# Out:
# array([[-3.99192001,  3.85760657],
#        [11.35683553, -0.96584262],
#        [10.41391051, -0.91907595],
#        ...,
#        [ 7.80873156,  3.48410363],
#        [10.04421488, -3.47051475],
#        [ 0.56917362,  6.89163241]])

# %%
color_dict = {0: 'blue', 1:'red'}

# %%
for data, label in zip(x, y):
    plt.scatter(data[0], data[1], c = color_dict[label])

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y)

# %%
clf = SVC(kernel = 'linear')

# %%
clf.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
clf.score(X_train, y_train)
# Out:
# 0.968

# %%
clf.score(X_test, y_test)
# Out:
# 0.96

# %%
plot_decision_regions(x, y, clf, colors = 'blue,red')

# %%
clf = SVC(kernel = 'poly')

# %%
clf.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='poly', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
plot_decision_regions(x, y, clf, colors = 'blue,red')

# %%
clf.score(X_train, y_train)
# Out:
# 0.9573333333333334

# %%
clf.score(X_test, y_test)
# Out:
# 0.96

# %%
def check_svm(x, y, kernel):
    X_train, X_test, y_train, y_test = train_test_split(x, y, random_state = 11)
    clf = SVC(kernel = kernel)
    clf.fit(X_train, y_train)
    print(f'Training Accuracy: {clf.score(X_train, y_train)}')
    print(f'Testing Accuracy: {clf.score(X_test, y_test)}')
    return plot_decision_regions(x, y, clf, colors = 'blue,red')

# %%
check_svm(x, y, 'rbf')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Training Accuracy: 0.976
# Testing Accuracy: 0.956

# %%
check_svm(x, y, 'sigmoid')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Training Accuracy: 0.7506666666666667
# Testing Accuracy: 0.788

# %%
x, y = make_circles(n_samples = 1000, shuffle = True, noise = 0.1)

# %%
color_dict = {0: 'red', 1: "blue"}
for data, label in zip(x, y):
    plt.scatter(data[0], data[1], c = color_dict[label])

# %%
check_svm(x, y, 'linear')
# Out:
# Training Accuracy: 0.5106666666666667
# Testing Accuracy: 0.464

# %%
check_svm(x, y, 'poly')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Training Accuracy: 0.508
# Testing Accuracy: 0.476

# %%
check_svm(x, y, 'rbf')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Training Accuracy: 0.8546666666666667
# Testing Accuracy: 0.84

# %%
check_svm(x, y, 'sigmoid')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Training Accuracy: 0.4666666666666667
# Testing Accuracy: 0.416

# %%
x, y = make_moons(n_samples=1000, noise=.1)

# %%
def plot_fake_data(x, y):
    color_dict = {0: 'red', 1: 'blue'}
    for data, label in zip(x, y):
        plt.scatter(data[0], data[1], c = color_dict[label])

# %%
plot_fake_data(x, y)

# %%
check_svm(x, y, 'linear')
# Out:
# Training Accuracy: 0.8746666666666667
# Testing Accuracy: 0.876

# %%
check_svm(x, y, 'poly')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Training Accuracy: 0.9253333333333333
# Testing Accuracy: 0.944

# %%
check_svm(x, y, 'rbf')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Training Accuracy: 0.9946666666666667
# Testing Accuracy: 0.996

# %%
check_svm(x, y, 'sigmoid')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Training Accuracy: 0.6786666666666666
# Testing Accuracy: 0.724
